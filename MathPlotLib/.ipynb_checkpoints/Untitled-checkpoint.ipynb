# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Basic Graph

# %%
x=[1,2,3]
y=[2,4,6]
plt.plot(x,y)
plt.title('First Graph!',fontdict={'fontname': 'COmic Sans MS'})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
